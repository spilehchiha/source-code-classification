# %% [markdown]
# <a href="https://colab.research.google.com/github/spilehchiha/source-code-classification/blob/master/For_Jincheng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pyarrow.parquet as pq

# %%
import pyarrow.csv as pqc

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
dataset = pq.read_table("/content/gdrive/My Drive/Europe_Network_data.parquet")

# %%
print(type(dataset))
# Out:
# <class 'pyarrow.lib.Table'>

# %%
dataset.columns
# Out:
# [<Column name='ID' type=DataType(string)>
#  [
#    [
#      "Device0",
#      "Device1",
#      "Device2",
#      "Device3",
#      "Device4",
#      "Device5",
#      "Device6",
#      "Device7",
#      "Device8",
#      "Device9",
#      ...
#      "Device73355",
#      "Device36035",
#      "Device34384",
#      "Device45550",
#      "Device13863",
#      "Device17135",
#      "Device84623",
#      "Device94423",
#      "Device21164",
#      "Device35714"
#    ]
#  ], <Column name='TIME' type=TimestampType(timestamp[ms])>
#  [
#    [
#      1547164800000,
#      1544572800000,
#      1544486400000,
#      1544486400000,
#      1544227200000,
#      1545609600000,
#      1544227200000,
#      1545609600000,
#      1543881600000,
#      1543363200000,
#      ...
#      1543363200000,
#      1543536000000,
#      1542931200000,
#      1542844800000,
#      1542672000000,
#      1542499200000,
#      1543104000000,
#      1543968000000,
#      1543622400000,
#      1544054400000
# ...
